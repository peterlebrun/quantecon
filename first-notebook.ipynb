# %%
import numpy as np
import matplotlib.pyplot as plt

N = 20
Θ = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)

ax = plt.subplot(111, polar=True)
bars = ax.bar(Θ, radii, width=width, bottom=0.0)

# Use custom colors and opacity
for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.jet(r / 10.))
    bar.set_alpha(0.5)
    
plt.show()

# %%
np.rank?

# %% [markdown]
# If $\{A_n\}$ is pairwise disjoint, then
# $$ \mu(\cup_n A_n) = \sum_m \mu(A_n) $$

# %%
# !pip install --upgrade quantecon
# Out:
# Requirement already up-to-date: quantecon in /Users/p/anaconda3/lib/python3.7/site-packages (0.4.5)
# Requirement already satisfied, skipping upgrade: requests in /Users/p/anaconda3/lib/python3.7/site-packages (from quantecon) (2.22.0)
# Requirement already satisfied, skipping upgrade: scipy>=1.0.0 in /Users/p/anaconda3/lib/python3.7/site-packages (from quantecon) (1.3.1)
# Requirement already satisfied, skipping upgrade: sympy in /Users/p/anaconda3/lib/python3.7/site-packages (from quantecon) (1.4)
# Requirement already satisfied, skipping upgrade: numpy in /Users/p/anaconda3/lib/python3.7/site-packages (from quantecon) (1.17.2)
# Requirement already satisfied, skipping upgrade: numba>=0.38 in /Users/p/anaconda3/lib/python3.7/site-packages (from quantecon) (0.45.1)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /Users/p/anaconda3/lib/python3.7/site-packages (from requests->quantecon) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Users/p/anaconda3/lib/python3.7/site-packages (from requests->quantecon) (2019.9.11)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /Users/p/anaconda3/lib/python3.7/site-packages (from requests->quantecon) (2.8)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/p/anaconda3/lib/python3.7/site-packages (from requests->quantecon) (1.24.2)
# Requirement already satisfied, skipping upgrade: mpmath>=0.19 in /Users/p/anaconda3/lib/python3.7/site-packages (from sympy->quantecon) (1.1.0)
# Requirement already satisfied, skipping upgrade: llvmlite>=0.29.0dev0 in /Users/p/anaconda3/lib/python3.7/site-packages (from numba>=0.38->quantecon) (0.29.0)

# %%
# !pip install interpolation
# Out:
# Collecting interpolation
#   Downloading https://files.pythonhosted.org/packages/52/35/d760068c72b479bbc319c3f46daecbbb975df3077269ad971aa495fa4c17/interpolation-2.1.2-py3-none-any.whl (66kB)
#      |████████████████████████████████| 71kB 1.9MB/s eta 0:00:01
# Requirement already satisfied: numba in /Users/p/anaconda3/lib/python3.7/site-packages (from interpolation) (0.45.1)
# Requirement already satisfied: numpy in /Users/p/anaconda3/lib/python3.7/site-packages (from interpolation) (1.17.2)
# Collecting tempita (from interpolation)
#   Downloading https://files.pythonhosted.org/packages/56/c8/8ed6eee83dbddf7b0fc64dd5d4454bc05e6ccaafff47991f73f2894d9ff4/Tempita-0.5.2.tar.gz
# Requirement already satisfied: scipy in /Users/p/anaconda3/lib/python3.7/site-packages (from interpolation) (1.3.1)
# Requirement already satisfied: llvmlite>=0.29.0dev0 in /Users/p/anaconda3/lib/python3.7/site-packages (from numba->interpolation) (0.29.0)
# Building wheels for collected packages: tempita
#   Building wheel for tempita (setup.py) ... done
#   Created wheel for tempita: filename=Tempita-0.5.2-cp37-none-any.whl size=12881 sha256=c33b3d6a06ab29d54e6b945c60d90f607ecac15bb7daee368073afaad36b4df6
#   Stored in directory: /Users/p/Library/Caches/pip/wheels/1e/db/04/d827f417f162a149fbdfdd1d015c7769b393124aa98eb29642
# Successfully built tempita
# Installing collected packages: tempita, interpolation
# Successfully installed interpolation-2.1.2 tempita-0.5.2

# %%
# %run test.py
# Out:
# foobar
# foobar
# foobar
# foobar
# foobar

# %%
run test.py
# Out:
# foobar
# foobar
# foobar
# foobar
# foobar

# %%
pwd
# Out:
# '/Users/p/eng/github.com/peterlebrun/quantecon'

# %%
# %pwd
# Out:
# '/Users/p/eng/github.com/peterlebrun/quantecon'

# %%
# %ls
# Out:
# first-notebook.ipynb  test.py

# %%
# %cat test.py
# Out:
# for i in range(5):
#     print('foobar')

# %%
cd ~/
# Out:
# /Users/p

# %%
# %pwd
# Out:
# '/Users/p'

# %%
# %load white_noise.py
from pylab import plot, show, legend
from random import normalvariate

x = [normalvariate(0, 1) for i in range(100)]
plot(x, 'b-', label="white noise")
legend()
show()

# %%
# %pwd
# Out:
# '/Users/p'

# %%
cd ~/eng/github.com/peterlebrun/quantecon/
# Out:
# /Users/p/eng/github.com/peterlebrun/quantecon

# %%
# %matplotlib inline
# %run white_noise.py

# %%
# %%file white_noise_2.py
from pylab import plot, show, legend
from random import normalvariate

x = [normalvariate(0, 1) for i in range(100)]
plot(x, 'b-', label="white noise")
legend()
show()
# Out:
# Writing white_noise_2.py
